# %% [markdown]
# <a href="https://colab.research.google.com/github/27luiz/Tratamento_dados-PY/blob/main/Analise_exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sweetviz
import pandas as pd
import sweetviz as vz
import numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 53.2 MB/s eta 0:00:00
# ...

# %%
df = pd.read_csv(r'/content/BD Extrato BH 2024.csv')
df.head(3)
# Out:
#                   DATA NOME_GRUPO       NOME_SUBGRUPO              NOME_ITEM  \
# 0  2024-01-05 00:00:00    PESSOAL  FOLHA DE PAGAMENTO  SALARIOS - ENFERMAGEM
# 1  2024-03-06 00:00:00    PESSOAL  FOLHA DE PAGAMENTO  SALARIOS - ENFERMAGEM
# 2  2024-01-08 00:00:00    PESSOAL  FOLHA DE PAGAMENTO  SALARIOS - ENFERMAGEM
#
#    ID_GSI  BCO_CRE  BCO_DEV   VALOR                                HIST
# 0  101O12        0      238     476  PG PENSÃO ALIMENTICIA FILHA SILVIO
# 1  101O12        0      238   503,6     PENSAO ISABELLA FILHA DO SILVIO
# 2  101O12        0      238  5052,1   PAG GEMIMA SALARIO PERICULOSIDADE

# %%
my_report = vz.analyze(df)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATA           135 non-null    object
#  1   NOME_GRUPO     135 non-null    object
#  2   NOME_SUBGRUPO  135 non-null    object
#  3   NOME_ITEM      135 non-null    object
#  4   ID_GSI         135 non-null    object
#  5   BCO_CRE        135 non-null    int64
#  6   BCO_DEV        135 non-null    int64
#  7   VALOR          135 non-null    object
#  8   HIST           135 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 9.6+ KB
# None

# %%
# Substitua a vírgula por um ponto e, em seguida, converta para um número inteiro
df['VALOR'] = df['VALOR'].str.replace(',', '.').astype(float).astype('int64')

# %%
# Convertendo a coluna 'DATA' para o tipo datetime com formato 'dd/mm/aaaa'
df['DATA'] = pd.to_datetime(df['DATA'])

# %%
df['DATA'] = pd.to_datetime(df['DATA'])

# %%
df[['BCO_CRE','BCO_DEV' ]]= df[['BCO_CRE','BCO_DEV']].astype('object')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATA           135 non-null    datetime64[ns]
#  1   NOME_GRUPO     135 non-null    object
#  2   NOME_SUBGRUPO  135 non-null    object
#  3   NOME_ITEM      135 non-null    object
#  4   ID_GSI         135 non-null    object
#  5   BCO_CRE        135 non-null    object
#  6   BCO_DEV        135 non-null    object
#  7   VALOR          135 non-null    int64
#  8   HIST           135 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 9.6+ KB
# None

# %%
my_report = vz.analyze(df)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df_credito = df[df['BCO_CRE'] != 0]
df_credito.head()
# Out:
#          DATA                 NOME_GRUPO   NOME_SUBGRUPO           NOME_ITEM  \
# 86 2024-01-09       RECEITA OPERACIONAIS      PARTICULAR  PARTICULAR A VISTA
# 87 2024-02-14       RECEITA OPERACIONAIS  ESTUDO CLINICO      ESTUDO CLINICO
# 88 2024-01-10       RECEITA OPERACIONAIS  ESTUDO CLINICO      ESTUDO CLINICO
# 89 2024-02-05  RECEITAS NÃO OPERACIONAIS          OUTROS              OUTROS
# 90 2024-03-14  RECEITAS NÃO OPERACIONAIS          OUTROS              OUTROS
#
#     ID_GSI BCO_CRE BCO_DEV  VALOR                              HIST
# 86  200O12     238       0  29750           PG PCTE DRA. TEREZA EEF
# 87  200O51     904       0  16326        TRANSF RECEB SOC BENEF ISR
# 88  200O51     904       0  19411   REPASSE ESTUDO SERMIC HOSP. ISR
# 89  205O11     238       0      2                             ACRES
# 90  205O11     238       0    340  PAG REEMBOLSO CAFE DIA DA MULHER

# %%
df_debito = df[df['BCO_DEV'] != 0]
df_debito.head()
# Out:
#         DATA          NOME_GRUPO       NOME_SUBGRUPO              NOME_ITEM  \
# 0 2024-01-05             PESSOAL  FOLHA DE PAGAMENTO  SALARIOS - ENFERMAGEM
# 1 2024-03-06             PESSOAL  FOLHA DE PAGAMENTO  SALARIOS - ENFERMAGEM
# 2 2024-01-08             PESSOAL  FOLHA DE PAGAMENTO  SALARIOS - ENFERMAGEM
# 3 2024-01-02             PESSOAL          BENEFICIOS          VALE REFEIÇÃO
# 4 2024-01-15  HONORÁRIOS MÉDICOS  HONORÁRIOS MÉDICOS     HONORÁRIOS MÉDICOS
#
#    ID_GSI BCO_CRE BCO_DEV  VALOR                                HIST
# 0  101O12       0     238    476  PG PENSÃO ALIMENTICIA FILHA SILVIO
# 1  101O12       0     238    503     PENSAO ISABELLA FILHA DO SILVIO
# 2  101O12       0     238   5052   PAG GEMIMA SALARIO PERICULOSIDADE
# 3  101O21       0     238    180  PG SILVANIA 10 DIAS DE TICKET REST
# 4  102O21       0     238   1200      ANESTESISTA EEF DIA 13/01/2024

# %%
my_report2 = vz.compare([df_credito, 'credito'], [df_debito,'debito'])
my_report2.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
